# %% [markdown]
# # 安装
#
# 首先安装 [Anaconda](http://www.continuum.io/downloads)
#
# 安装：pip install tushare
#
# 升级：pip install tushare --upgrade

# %%
# 检查
import tushare as ts
print(ts.__version__)
# Out:
# 0.8.4

# %% [markdown]
# # 获取数据

# %% [markdown]
# ## 基本面数据
# 数据来自sina财经，由于财务数据项目比较多，所以拆分成了几个表，使用时可以通过股票代码合并在一起，也可以独立使用。数据在获取时，需要一页一页的抓取，所以需要一点等待时间，最后会合并成一个大表。
#
# ### 股票列表

# %%
stock_basic = ts.get_stock_basics()
stock_basic.head(5)
# Out:
#         name industry area       pe  outstanding  totals  totalAssets  \
# code
# 002892  N科力尔     电气设备   湖南    29.21         0.18    0.84     45364.44
# 603776  N永安行     公共交通   江苏    30.24         0.24    0.96    151001.23
# 601326  秦港股份       港口   河北    16.80         5.58   55.87   2604904.25
# 002175  东方网络     电器仪表   广西    66.28         5.18    7.54    311620.25
# 002194  武汉凡谷     通信设备   湖北     0.00         5.22    5.65    243919.77
# 600072  中船科技       船舶   上海  1065.88         3.10    7.36   1142123.13
# 002542  中化岩土     建筑施工   北京   139.91         6.22   18.00    555334.00
# 000688  建新矿业       铅锌   重庆    31.97        11.37   11.37    201976.56
# 002780  三夫户外     其他商业   北京  3012.02         0.51    1.01     54961.51
# 002386  天原集团     化工原料   四川   142.12         6.72    6.72   1413259.63
#
#         liquidAssets  fixedAssets   reserved   ...     bvps    pb  \
# code                                           ...
# 002892      27348.35     16422.97   10559.05   ...     4.08  6.20
# 603776      80017.61     13221.05   18186.32   ...     8.35  4.63
# 601326     378642.06   1140481.38  450637.81   ...     2.40  1.55
# 002175     129172.56     14333.55   52518.11   ...     1.98  5.65
# 002194     178515.31     45737.78   82533.31   ...     3.12  2.84
# 600072     644566.75     42294.71  243876.00   ...     4.93  3.76
# 002542     356518.34     91404.36   73689.18   ...     1.83  6.53
# 000688      66866.55     63473.60   18883.17   ...     1.62  6.03
# 002780      40949.05      1153.22   13793.55   ...     3.89  7.12
# 002386     413625.00    597320.25  185366.23   ...     6.06  1.83
#
#         timeToMarket       undp  perundp    rev   profit    gpr    npr  \
# code
# 002892      20170817    8897.21     1.06   0.00     0.00  28.04  12.92
# 603776      20170817   32058.58     3.34   0.00     0.00  28.31  12.93
# 601326      20170816  144972.61     0.26   0.00     0.00  38.15  18.18
# 002175      20071012   19157.17     0.25  71.40   885.07  54.90  16.63
# 002194      20071207   17823.45     0.32 -13.15 -4962.80 -10.51 -29.61
# 600072      19970603   23911.10     0.32 -41.37    24.91  11.40   0.49
# 002542      20110128   67297.60     0.37  -4.72    10.13  28.16   9.37
# 000688      19970120   32291.84     0.28  38.67   761.16  60.31  37.50
# 002780      20151209   14766.95     1.46  16.23   -93.09  43.96   0.28
# 002386      20100409  128989.26     1.92   2.67   140.39   6.70   0.44
#
#         holders
# code
# 002892    37145
# 603776    25199
# 601326   423429
# 002175    66546
# 002194    35108
# 600072    84106
# 002542    37487
# 000688    45310
# 002780    20362
# 002386    48453
#
# [10 rows x 22 columns]

# %% [markdown]
# 返回值说明：
# * code,代码
# * name,名称
# * industry,所属行业
# * area,地区
# * pe,市盈率
# * outstanding,流通股本
# * totals,总股本(万)
# * totalAssets,总资产(万)
# * liquidAssets,流动资产
# * fixedAssets,固定资产
# * reserved,公积金
# * reservedPerShare,每股公积金
# * eps,每股收益
# * bvps,每股净资
# * pb,市净率
# * timeToMarket,上市日期
#
# 如果是使用自己的数据，只要表头与默认文件格式一致，可设定文件路径的方式读入，例如：ts.get_stock_basics("c:\all_stocks.csv")

# %% [markdown]
# ### 业绩报告（主表）
#
# 按年度、季度获取业绩报表数据。

# %%
# 获取 2016 年第 4 季度的业绩报表数据
report = ts.get_report_data(2016, 4)
report.head(5)
# Out:
# [Getting data:]########################################################
#      code  name   eps  eps_yoy  bvps    roe  epcf  net_profits  profits_yoy  \
# 0  002892   科力尔  1.02    13.33  3.70  31.59  0.96      6751.32        13.10
# 1  603129  春风动力  0.88    23.94  3.87  25.42  2.47      8826.78        48.89
# 2  603557  起步股份  0.42     7.69  2.29  19.97  0.24     17566.54        16.62
# 3  300688  创业黑马  0.79   618.18  3.46  26.18  0.84      4053.80       660.68
# 4  300689  澄天伟业  0.83    53.70  5.26  17.52  1.28      4257.77        54.65
#
#   distrib report_date
# 0     NaN       07-31
# 1     NaN       07-31
# 2     NaN       07-31
# 3     NaN       07-27
# 4     NaN       07-27

# %% [markdown]
# 返回值说明：
# * code,代码
# * name,名称
# * eps,每股收益
# * eps_yoy,每股收益同比(%)
# * bvps,每股净资产
# * roe,净资产收益率(%)
# * epcf,每股现金流量(元)
# * net_profits,净利润(万元)
# * profits_yoy,净利润同比(%)
# * distrib,分配方案
# * report_date,发布日期

# %% [markdown]
# ### 盈利能力
#
# 按年度、季度获取盈利能力数据

# %%
# 获取 2016 年第 4 季度的盈利能力数据
profit = ts.get_profit_data(2016, 4)
profit.head(5)
# Out:
# [Getting data:]########################################################
#      code  name      roe  net_profit_ratio  gross_profit_rate  net_profits  \
# 0  600725  ST云维  1610.61             82.54            -1.7784    1544.5634
# 1  000504  南华生物   412.63             32.35            32.2189      21.7561
# 2  600319  亚星化学   364.40              1.83             4.2111      26.7817
# 3  600265  ST景谷   166.14             47.66             6.9047      33.7095
# 4  600306   商业城   165.40             11.45            17.7831     110.7098
#
#       eps  business_income    bips
# 0  1.2532        1871.1586  1.5182
# 1  0.0698          67.2514  0.2158
# 2  0.0848        1457.4376  4.6180
# 3  0.2597          70.7183  0.5448
# 4  0.6214         966.8276  5.4273

# %% [markdown]
# 返回值说明：
# * code,代码
# * name,名称
# * roe,净资产收益率(%)
# * net_profit_ratio,净利率(%)
# * gross_profit_rate,毛利率(%)
# * net_profits,净利润(万元)
# * eps,每股收益
# * business_income,营业收入(百万元)
# * bips,每股主营业务收入(元)

# %% [markdown]
# ### 营运能力
#
# 按年度、季度获取营运能力数据

# %%
# 获取 2016 年第 4 季度的营运能力数据
operation = ts.get_operation_data(2016, 4)
operation.head(5)
# Out:
# [Getting data:]########################################################
#      code  name  arturnover  arturndays  inventory_turnover  inventory_days  \
# 0  600870  厦华电子    146.1882      2.4626         205580.4633          0.0018
# 1  002649  博彦科技      4.6886     76.7820          61592.0910          0.0058
# 2  300467  迅游科技     47.4756      7.5828          21278.1427          0.0169
# 3  002707  众信旅游     20.7980     17.3094          10166.5339          0.0354
# 4  000415  渤海金控     18.1215     19.8659          10065.5801          0.0358
#
#    currentasset_turnover  currentasset_days
# 0                 8.4939            42.3834
# 1                 1.3914           258.7322
# 2                 0.3485          1032.9986
# 3                 4.4087            81.6567
# 4                 0.5615           641.1398

# %% [markdown]
# 返回值说明：
# * code,代码
# * name,名称
# * arturnover,应收账款周转率(次)
# * arturndays,应收账款周转天数(天)
# * inventory_turnover,存货周转率(次)
# * inventory_days,存货周转天数(天)
# * currentasset_turnover,流动资产周转率(次)
# * currentasset_days,流动资产周转天数(天)

# %% [markdown]
# ### 成长能力
#
# 按年度、季度获取成长能力数据

# %%
# 获取 2016 年第 4 季度的成长能力数据
growth = ts.get_growth_data(2016, 4)
growth.head(5)
# Out:
# [Getting data:]########################################################
#      code  name       mbrg          nprg         nav        targ        epsg  \
# 0  002468  申通快递   583.0083  4.086723e+06    616.2619    407.1716  10150.0000
# 1  000892  欢瑞世纪  5396.8966  2.028534e+04  63009.3168  37643.7526  19900.0000
# 2  300189  神农基因   248.4390  1.806443e+04      1.9729     41.9041    127.3973
# 3  002352  顺丰控股  8499.2014  1.645667e+04   2803.4748   4884.6749    381.8182
# 4  002067  景兴纸业    24.6052  1.505320e+04     11.4982     -0.4867   2800.0000
#
#           seg
# 0    647.4373
# 1  63009.3168
# 2      1.0553
# 3   2797.1335
# 4     11.9269

# %% [markdown]
# 返回值说明：
# * code,代码
# * name,名称
# * mbrg,主营业务收入增长率(%)
# * nprg,净利润增长率(%)
# * nav,净资产增长率
# * targ,总资产增长率
# * epsg,每股收益增长率
# * seg,股东权益增长率
